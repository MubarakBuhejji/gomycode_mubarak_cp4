# %%
# In this cell we are going to read the data and run a general analysis.

# Import needed libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Read the data
df = pd.read_csv ('kc_house_data.csv',sep=',' )

# Display and examine the data using different params for the head method e.g. head(10), head (50)
# Note alternatively we can use the print method instead of display, but the display method shows a better-styled output
# display(df.head(10))

# # Show some basic info about the data using the info method
# # Note this will help us idenfify non-numeric data types and the number of rows with null/nan values for each column/var
# print(df.info())
df.describe()


# Note about output:
# we have five float columns, 15 integer columns and 1 object columns

# with reference to the types of data in data science calssification, we have the following:

# id : categorical, nominal , note that even though id has numeric data type we cannot really classify it as numeric
# variable because it does not represent a measurable, classfiable or countable quantity. In stead it is merely a
# a unique identifier of each house. So it seems to be logical to regard it as categorical variable. Moreover the lack
# order and comparability between id values rules out the possibilty of regarding it as ordinal. 

# date: numeric, continous
# Note that the classification of date in terms of variable type, is debatble. In fact it might possible that date 
# is classified into any of the available variable types. But for our purposes we will consider it numeric and
# continous because we need to examin any possible corrlation between date and price. Also note that date is provided
# as integer data type, so we might need to convert it to float somehow...

# price: numeric, continous
# bedrooms: numeric, discret
# bathrooms: numeric, discret
# Now this is really tricky. Logically something like the count of bathrooms in a house should obviously be of numeric
# and discrete variable type. This is because bathrooms are countable and can and should be represented via integers. 
# What we have in our data is float data type for the bathroom variable. In fact some values contain decimal fractions.
# This can be traced to the fact that sometimes bathorrms with only w/c are considered as "half" bathrooms and thus 
# have the value 0.5. 
# sqft_living: numeric, continous
# sqft_lot: numeric, continous
# floors: numeric, discret
# waterfront: numeric, discret , actually it looks like waterfront was originally categorical nominal variable that 
# got encoded. 
# view: categorical, ordinal , so looking at the minimum which is 0 and the maximum which is 4 we can see that this
# like a score of the quality of the view.
# condition: categorical, ordinal , so looking at the minimum which is 1 and the maximum which is 5 we can see that this
# like a score of the quality of the condition.
# grade: categorical, ordinal , so looking at the minimum which is 1 and the maximum which is 13 we can see that this
# like a score of the quality of the grade.
# sqft_above: numeric, continous
# sqft_basement: numeric, continous
# yr_built: Depending on the way you look at it it could numeric continous or catgorical ordinal or categorical nominal.
# yr_renovated: Depending on the way you look at it it could numeric continous or catgorical ordinal or categorical nominal.
# zipcode: catgorical nominal.
# lat: numeri  continous.
# long: numeri  continous.
# sqft_living15: numeric, continous
# sqft_lot15: numeric, continous
# no columns have missing data.


# v= df[(df['price'] <= 3000000)]
# plt.hist(v["price"], bins=30)
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
# In this cell we are going to read the data and have a look at the distribution of the variables.

# Import needed libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Read the data
df = pd.read_csv ('kc_house_data.csv',sep=',' )

# The distribution of important columns/varibles.
# sns_price = sns.displot(x= "price", data=df)
# sns_bedrooms = sns.catplot(x= "bedrooms", data=df, kind="count")
# sns_bathrooms = sns.displot(x= "bathrooms", data=df)
# sns_sqft_living = sns.displot(x= "sqft_living", data=df)
# sns_sqft_lot = sns.displot(x= "sqft_lot", data=df)
# sns.scatterplot(data=df, x="price", y="sqft_living")
g = sns.PairGrid(df, x_vars=['sqft_living','sqft_lot','bedrooms','bathrooms'], y_vars=['price'])
g.map(sns.scatterplot)

# %%
# In this cell we are going to read the data and have a look at the distribution of the variables.

# Import needed libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Read the data
df = pd.read_csv ('kc_house_data.csv',sep=',' )

# Lets get a general idea about the correlation between the variables, keeping in mind that we are looking
# to predict price based on the other variables.

# The quickest indication of correlation is the pearson correlation coefficient:

print(df.corr())

# 1- Price has medium positive correlation with bathrooms at 0.52.
# 2- Price has high positive correlation with sqft_living at 0.70.
# 3- Price has medium positive correlation with grade at 0.67.
# 4- Price has medium positive correlation with sqft_above at 0.60.
# 5- Price has medium positive correlation with sqft_living15 at 0.58.

# So those are the best candidates for our liner regression model to predict price.
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
# In this cell we are going to read the data and run a general analysis.

# Import needed libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

#Importing libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# Read the data
df = pd.read_csv ('kc_house_data.csv',sep=',' )


#extract x and y from our data
x=df[["sqft_living"]]  #we have more than one input

y=df["price"].values

# plt.scatter(x, y)

#split the data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%
x_train_scaled=fit_transform(x_train)

model=LinearRegression()   #build linear regression model
model.fit(x_train_scaled,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

print(model.score(x_train_scaled,y_train))
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
print("ME", metrics.mean_absolute_error(y_test,predicted))

# print(x)
# print(y)


plt.scatter(x, y, color="r")
plt.title("Linear regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x_test, predicted, color="k")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-83435cb087bc> in <module>
#      30 #split the data
#      31 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%
# ---> 32 x_train_scaled=fit_transform(x_train)
#      33
#      34 model=LinearRegression()   #build linear regression model
#
# NameError: name 'fit_transform' is not defined

# %%
# In this cell we are going to read the data and run a general analysis.

# Import needed libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

#Importing libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# Read the data
df = pd.read_csv ('kc_house_data.csv',sep=',' )


#extract x and y from our data
x=df[["bathrooms","sqft_living","grade","sqft_above","sqft_living15"]]  #we have more than one input

y=df["price"].values

# plt.scatter(x, y)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%
x_train_scaled=fit_transform(x_train)
model=LinearRegression()   #build linear regression model
model.fit(x_train_scaled,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

print(model.score(x_train_scaled,y_train))

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
print("ME", metrics.mean_absolute_error(y_test,predicted))

# print(x)
# print(y)


# plt.scatter(x, y, color="r")
# plt.title("Linear regression")
# plt.ylabel("price")
# plt.xlabel("multi_var")
# plt.plot(x_test, predicted, color="k")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-9803b3d792b9> in <module>
#      29
#      30 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%
# ---> 31 x_train_scaled=fit_transform(x_train)
#      32 model=LinearRegression()   #build linear regression model
#      33 model.fit(x_train_scaled,y_train)  #fitting the training data
#
# NameError: name 'fit_transform' is not defined

# %%
# Import needed libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

#Importing libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

from sklearn.preprocessing import PolynomialFeatures 


# Read the data
df = pd.read_csv ('kc_house_data.csv',sep=',' )

# x=df[["bathrooms","sqft_living","grade","sqft_above","sqft_living15"]]  #we have more than one input
x=df[["sqft_above"]].values
y= df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  #splitting data
lg.fit(x_train_scaled, y_train)
x_train_scaled=fit.transform(x_train)
lg=LinearRegression()
poly=PolynomialFeatures(degree=2)
predicted = lg.predict(x_test)

print(model.score(x_test,y_train))

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))


plt.scatter(x, y, color="r")
plt.title("Linear regression")
plt.ylabel("price")
plt.xlabel("sqft_above")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-7cab74a709ab> in <module>
#      26
#      27 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  #splitting data
# ---> 28 lg.fit(x_train_scaled, y_train)
#      29 x_train_scaled=fit.transform(x_train)
#      30 lg=LinearRegression()
#
# NameError: name 'x_train_scaled' is not defined

# %%
x_train_array = df['sqft_above'].values
print(x_train_array[0])
poly.transform(x_train_array[0].reshape(-1,1))
# Out:
# 1180
# array([[1.0000e+00, 1.1800e+03, 1.3924e+06]])

# %%
# Import needed libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

#Importing libraries
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

from sklearn.preprocessing import PolynomialFeatures 


# Read the data
df = pd.read_csv ('kc_house_data.csv',sep=',' )

x=df[["bathrooms","sqft_living","grade","sqft_above","sqft_living15"]]  #we have more than one input
# x=df[["sqft_above"]].values
y= df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print(model.score(x_test,y_test))

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))


# plt.scatter(x, y, color="r")
# plt.title("Linear regression")
# plt.ylabel("price")
# plt.xlabel("multi_var")
# plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-a288f16d2f8a> in <module>
#      34 predicted = lg.predict(x_test_)
#      35
# ---> 36 print(model.score(x_test,y_test))
#      37
#      38 print("MSE: ", metrics.mean_squared_error(y_test, predicted))
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     551
#     552         from .metrics import r2_score
# --> 553         y_pred = self.predict(X)
#     554         return r2_score(y, y_pred, sample_weight=sample_weight)
#     555
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     236             Returns predicted values.
#     237         """
# --> 238         return self._decision_function(X)
#     239
#     240     _preprocess_data = staticmethod(_preprocess_data)
#
# ...
